# %% [markdown]
# # Documentation
# ## Intro
# The dataset gives us a description of a wine with the taster, origin, points ranked, price, etc. The most interesting part is that of the taster name and the description that is given. Sentiment Analysis will be the main focus of this dataset, since we have that option.
#
# ## Documentation of steps I have taken
# ### 1
# Changed all countries below the top 10 most counted to 'other' to group smaller countries together without losing valuable data
# ### 2
# Removed all but the top 10 wines so that I have a more centralized data set, since many wines were unique and therefore hard to account for or combine to existing catagories
# ### 3
# Removed all Reviewers with below 100 reviews to keep consistancy for review
# ### 4
# Made all description lower cases,used stemming and snowballing
# ### 5
# Seperated into subsets for each reviewer, where each subset will be further split into training and test set. As well as the original set
# ### 6
# Divided each subset in train and test

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('winemag-data-130k-v2.csv')

# %%
df.sort_values('taster_name')
# Out:
#         Unnamed: 0 country                                        description  \
# 1836          1836      US  Grilled peach and almond notes show on the nos...
# 119882      119882      US  Inviting aromas of dark cherry, spicy bramble ...
# 79695        79695      US  Faint citrus and wilted floral aromas carry th...
# 79703        79703      US  A flabby nose of muddled citrus and bruised pe...
# 79706        79706      US  High-toned aromas of black cherry syrup and or...
# 79713        79713      US  Pollen and wilted-flower tones are mild on the...
# 69767        69767      US  Quite quinine and focused on the nose, underri...
# 79715        79715      US  SweeTART candies and green Jolly Rancher aroma...
# 69770        69770      US  This single-vineyard offering from northern Mi...
# 7959          7959      US  Pink grapefruit and lemon rind notes are eleva...
# 69771        69771      US  A mild concentration of peach, pineapple and a...
# ...

# %%
# See if needs to be removed
taster_mean=df[['points','price','taster_name']].groupby('taster_name').mean()
taster_mean.index.values
# Out:
# array(['Alexander Peartree', 'Anna Lee C. Iijima', 'Anne Krebiehl\xa0MW',
#        'Carrie Dykes', 'Christina Pickard', 'Fiona Adams', 'Jeff Jenssen',
#        'Jim Gordon', 'Joe Czerwinski', 'Kerin O’Keefe', 'Lauren Buzzeo',
#        'Matt Kettmann', 'Michael Schachner', 'Mike DeSimone',
#        'Paul Gregutt', 'Roger Voss', 'Sean P. Sullivan',
#        'Susan Kostrzewa', 'Virginie Boone'], dtype=object)

# %%
df[df['taster_name']=='Anne Krebiehl\xa0MW']
# Out:
#         Unnamed: 0  country  \
# 93              93  Austria
# 340            340   France
# 423            423  Austria
# 428            428  Austria
# 435            435  Austria
# 441            441  Austria
# 444            444  Austria
# 584            584  Austria
# 586            586  Austria
# 587            587  Austria
# 589            589  Austria
# 591            591  Austria
# 593            593  Austria
# 597            597  Austria
# 631            631   France
# 632            632   France
# 637            637   France
# 638            638   France
# 639            639   France
# 651            651   France
# 654            654   France
# 690            690  Austria
# 697            697  Austria
# 846            846   France
# 847            847   France
# 852            852   France
# 1101          1101  Austria
# 1320          1320  Austria
# 1322          1322  Austria
# 1341          1341  Austria
# ...            ...      ...
# 128967      128967  Austria
# ...

# %%
#note correlation between price and points, but not high enough to modify
corrmat = df.corr()
sns.heatmap(corrmat)

# %% [markdown]
# # Data cleaning

# %%
df.groupby('country').count().sort_values('winery',ascending=False)
# Out:
#                         Unnamed: 0  description  designation  points  price  \
# country
# US                           54504        54504        36908   54504  54265
# France                       22093        22093        14530   22093  17776
# Italy                        19540        19540        13889   19540  16914
# Spain                         6645         6645         5320    6645   6573
# Portugal                      5691         5691         5105    5691   4875
# Chile                         4472         4472         3879    4472   4416
# Argentina                     3800         3800         2902    3800   3756
# Austria                       3345         3345         2825    3345   2799
# Australia                     2329         2329         1640    2329   2294
# Germany                       2165         2165         2006    2165   2120
# New Zealand                   1419         1419          684    1419   1378
# ...

# %%
country_list=df.groupby('country').count().sort_values('winery',ascending=False)
country_list.index[:10]
# Out:
# Index(['US', 'France', 'Italy', 'Spain', 'Portugal', 'Chile', 'Argentina',
#        'Austria', 'Australia', 'Germany'],
#       dtype='object', name='country')

# %% [markdown]
# ### Countries analysis
# Through the same means we can modify countries that have inadequete data
#
# For the most accurate data I will be focusing on the top 10 countries
# 1. US
# 2. France
# 3. Italy
# 4. Spain
# 5. Portugal
# 6. Chile
# 7. Argentina
# 8. Austria
# 9. Australia
# 10. Germany
#
# And creating the Country 'other' to represent all other Countries

# %%
df['country']=np.where(df['country'].isin(country_list.index[:10]),df['country'],'other')

# %%
df.groupby('country').count().sort_values('winery',ascending=False)
# Out:
#            Unnamed: 0  description  designation  points  price  province  \
# country
# US              54504        54504        36908   54504  54265     54504
# France          22093        22093        14530   22093  17776     22093
# Italy           19540        19540        13889   19540  16914     19540
# Spain            6645         6645         5320    6645   6573      6645
# Portugal         5691         5691         5105    5691   4875      5691
# other            5387         5387         3502    5387   5187      5324
# Chile            4472         4472         3879    4472   4416      4472
# Argentina        3800         3800         2902    3800   3756      3800
# Austria          3345         3345         2825    3345   2799      3345
# Australia        2329         2329         1640    2329   2294      2329
# Germany          2165         2165         2006    2165   2120      2165
#
#            region_1  region_2  taster_name  taster_twitter_handle  title  \
# ...

# %%
df.groupby('variety').count().sort_values('winery',ascending=False)
# Out:
#                             Unnamed: 0  country  description  designation  \
# variety
# Pinot Noir                       13272    13272        13272         9893
# Chardonnay                       11753    11753        11753         7843
# Cabernet Sauvignon                9472     9472         9472         5801
# Red Blend                         8946     8946         8946         7457
# Bordeaux-style Red Blend          6915     6915         6915         3654
# Riesling                          5189     5189         5189         4394
# Sauvignon Blanc                   4967     4967         4967         2866
# Syrah                             4142     4142         4142         3066
# Rosé                              3564     3564         3564         2504
# Merlot                            3102     3102         3102         1630
# Nebbiolo                          2804     2804         2804         2239
# ...

# %%
wine_list=df.groupby('variety').count().sort_values('winery',ascending=False)
wine_list.index[:10]
# Out:
# Index(['Pinot Noir', 'Chardonnay', 'Cabernet Sauvignon', 'Red Blend',
#        'Bordeaux-style Red Blend', 'Riesling', 'Sauvignon Blanc', 'Syrah',
#        'Rosé', 'Merlot'],
#       dtype='object', name='variety')

# %% [markdown]
# ### Variety of wine
# Now we can do the same method of shrinking to the wines
#
# We will be using the top 10 wines
# 1. Pinot Noir
# 2. Cabernet Sauvignon
# 3. Chardonnay
# 4. Syrah
# 5. Red Blend
# 6. Zinfandel
# 7. Merlot
# 8. Sauvignon Blanc
# 9. Bordeaux-style Red Blend
# 10. Riesling

# %%
df=df[df['variety'].isin(wine_list.index[:10])]

# %%
df.groupby('variety').count().sort_values('winery',ascending=False)
# Out:
#                           Unnamed: 0  country  description  designation  \
# variety
# Pinot Noir                     13272    13272        13272         9893
# Chardonnay                     11753    11753        11753         7843
# Cabernet Sauvignon              9472     9472         9472         5801
# Red Blend                       8946     8946         8946         7457
# Bordeaux-style Red Blend        6915     6915         6915         3654
# Riesling                        5189     5189         5189         4394
# Sauvignon Blanc                 4967     4967         4967         2866
# Syrah                           4142     4142         4142         3066
# Rosé                            3564     3564         3564         2504
# Merlot                          3102     3102         3102         1630
#
#                           points  price  province  region_1  region_2  \
# variety
# Pinot Noir                 13272  12787     13269     12118      9036
# ...

# %%
df.groupby('taster_name').count().sort_values('country')
# Out:
#                     Unnamed: 0  country  description  designation  points  \
# taster_name
# Christina Pickard            3        3            3            0       3
# Fiona Adams                 11       11           11            6      11
# Carrie Dykes                67       67           67           51      67
# Alexander Peartree         187      187          187          136     187
# Jeff Jenssen               237      237          237          189     237
# Mike DeSimone              282      282          282          232     282
# Susan Kostrzewa            505      505          505          324     505
# Lauren Buzzeo             1035     1035         1035          680    1035
# Anne Krebiehl MW          1278     1278         1278         1138    1278
# Jim Gordon                2460     2460         2460         1525    2460
# Kerin O’Keefe             2798     2798         2798         1945    2798
# ...

# %%
taster_list=df.groupby('taster_name').count().sort_values('country')
taster_list.index[3:]
# Out:
# Index(['Alexander Peartree', 'Jeff Jenssen', 'Mike DeSimone',
#        'Susan Kostrzewa', 'Lauren Buzzeo', 'Anne Krebiehl MW', 'Jim Gordon',
#        'Kerin O’Keefe', 'Joe Czerwinski', 'Anna Lee C. Iijima',
#        'Sean P. Sullivan', 'Matt Kettmann', 'Michael Schachner',
#        'Paul Gregutt', 'Virginie Boone', 'Roger Voss'],
#       dtype='object', name='taster_name')

# %% [markdown]
# ### Taster analysis
# With count we can determine which tasters we can remove due to having too little data
#
# Here we will remove:
# 1. Christina Pickard
# 2. Fiona Adams
# 3. Carrie Dykes

# %%
df = df[df['taster_name'].isin(taster_list.index[3:])]

# %%
#normal distribution
df['points'].hist()

# %%
df.groupby('taster_name').count().sort_values('winery')
# Out:
#                     Unnamed: 0  country  description  designation  points  \
# taster_name
# Alexander Peartree         187      187          187          136     187
# Jeff Jenssen               237      237          237          189     237
# Mike DeSimone              282      282          282          232     282
# Susan Kostrzewa            505      505          505          324     505
# Lauren Buzzeo             1035     1035         1035          680    1035
# Anne Krebiehl MW          1278     1278         1278         1138    1278
# Jim Gordon                2460     2460         2460         1525    2460
# Kerin O’Keefe             2798     2798         2798         1945    2798
# Joe Czerwinski            3047     3047         3047         1924    3047
# Anna Lee C. Iijima        3229     3229         3229         2735    3229
# Sean P. Sullivan          3506     3506         3506         2509    3506
# ...

# %% [markdown]
# # Parsing and Tokenizing

# %%
import nltk
#nltk.download('averaged_perceptron_tagger')
#nltk.download('punkt')
#nltk.download('stopwords')

# %%
sentiment_features=pd.DataFrame()

# %%
#Created seperate dataframe to allow streamline process
sentiment_features['tokenize']=df['description']
sentiment_features['tokenize']=sentiment_features['tokenize'].str.lower()
sentiment_features['taster_name']=df['taster_name']

# %%
#Used mean of normally distributed points to determine what constitutes as a negative and positive review
sentiment_features['class']=np.where(df['points']>df['points'].mean(),1,0)
sentiment_features['points']=df['points']

# %%
sentiment_features
# Out:
#                                                  tokenize         taster_name  \
# 3       pineapple rind, lemon pith and orange blossom ...  Alexander Peartree
# 4       much like the regular bottling from 2012, this...        Paul Gregutt
# 10      soft, supple plum envelopes an oaky structure ...      Virginie Boone
# 12      slightly reduced, this wine offers a chalky, t...      Virginie Boone
# 14      building on 150 years and six generations of w...       Matt Kettmann
# 15      zesty orange peels and apple notes abound in t...  Anna Lee C. Iijima
# 20      ripe aromas of dark berries mingle with ample ...  Alexander Peartree
# 21      a sleek mix of tart berry, stem and herb, alon...        Paul Gregutt
# 23      this wine from the geneseo district offers aro...       Matt Kettmann
# 25      oak and earth intermingle around robust aromas...      Virginie Boone
# 28      aromas suggest mature berry, scorched earth, a...       Kerin O’Keefe
# ...

# %%
#Checking for nulls
sentiment_features.isnull().sum()
# Out:
# tokenize       0
# taster_name    0
# class          0
# points         0
# dtype: int64

# %%
#Looking means to see if anything stands out
#Alexander Peartree has the lowerest positive reviews
sentiment_features.groupby('taster_name').mean()
# Out:
#                        class     points
# taster_name
# Alexander Peartree  0.080214  86.000000
# Anna Lee C. Iijima  0.519046  88.722515
# Anne Krebiehl MW    0.862285  91.062598
# Jeff Jenssen        0.476793  87.940928
# Jim Gordon          0.486992  88.479675
# Joe Czerwinski      0.494257  88.384312
# Kerin O’Keefe       0.482130  88.678342
# Lauren Buzzeo       0.344928  87.550725
# Matt Kettmann       0.698138  90.189938
# Michael Schachner   0.250407  86.588408
# Mike DeSimone       0.723404  89.446809
# Paul Gregutt        0.596961  89.308012
# Roger Voss          0.502555  88.784565
# Sean P. Sullivan    0.531945  88.898175
# Susan Kostrzewa     0.182178  86.263366
# Virginie Boone      0.610598  89.440856

# %% [markdown]
# # Create Sentiment analysis training and test set

# %% [markdown]
# Will be making an assamble model for individual tasters and general tasters

# %%
from sklearn.model_selection import train_test_split

# %%
#Creating Dic to hold individual reviewers scores
Training_Dic={}
Test_Dic={}
names_array=taster_list.index[3:]

# %%
#Checking to make sure names are stored properly
for name in names_array:
    print(name)
# Out:
# Alexander Peartree
# Jeff Jenssen
# Mike DeSimone
# Susan Kostrzewa
# Lauren Buzzeo
# Anne Krebiehl MW
# Jim Gordon
# Kerin O’Keefe
# Joe Czerwinski
# Anna Lee C. Iijima
# Sean P. Sullivan
# Matt Kettmann
# Michael Schachner
# Paul Gregutt
# Virginie Boone
# Roger Voss

# %%
#creating subset train and test
for name in names_array:
    Training_Dic[name],Test_Dic[name] = train_test_split(sentiment_features[sentiment_features['taster_name']==name], train_size=.80)
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
Train_set, Test_set = train_test_split(sentiment_features, train_size=.80)

# %%
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')

# %%
for name in names_array:
    Training_Dic[name].tokenize=Training_Dic[name].tokenize.str.split()

# %%
Train_set['tokenize']=Train_set['tokenize'].str.split()
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Remove stop words from both general and ind. sets

# %%
#Using lamba function to create a for loop that goes through each description
for name in names_array:
    Training_Dic[name].tokenize=Training_Dic[name].tokenize.apply(lambda x: [item for item in x if item not in stop])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6634f3db9a91> in <module>
# ----> 1 for name in names_array:
#       2     Training_Dic[name].tokenize=Training_Dic[name].tokenize.apply(lambda x: [item for item in x if item not in stop])
#
# NameError: name 'names_array' is not defined

# %%
Train_set['tokenize']=Train_set['tokenize'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Usign snowballer to have only stem words remaining

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
#testing
stemmer = SnowballStemmer("english")
print(stemmer.stem("governmental"))
# Out:
# government

# %%
for name in names_array:
    Training_Dic[name].tokenize=Training_Dic[name].tokenize.apply(lambda x:[stemmer.stem(item) for item in x])

# %%
Train_set['tokenize']=Train_set['tokenize'].apply(lambda x:[stemmer.stem(item) for item in x])
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Rejoining words

# %%
for name in names_array:
    Training_Dic[name].tokenize=Training_Dic[name].tokenize.str.join(" ")

# %%
Train_set['tokenize']=Train_set['tokenize'].str.join(" ")
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Train_set
# Out:
#                                                  tokenize         taster_name  \
# 72008   friend flavorful, offer bright butter fruit ar...          Jim Gordon
# 24882   variet familiar aroma petrol white fruit set t...   Michael Schachner
# 118026  salin almost dilut nose, beli richer banana va...   Michael Schachner
# 78573   scent blossom fresh appl off-dri riesl suggest...  Anna Lee C. Iijima
# 79495   even dispers nose sage bark, cherri compot lig...       Matt Kettmann
# 115017  demonstr fine balanc crisp white peach fruit n...          Roger Voss
# 95336   nose reveal noth slightest creaminess. palat a...    Anne Krebiehl MW
# 38451   one ocean-adjac vineyard state, swarthi power ...       Matt Kettmann
# 40959   here simpl well made red tuscani floral aroma ...       Kerin O’Keefe
# 85189   fourth-gener farm family, wine sourc niebaum-t...      Virginie Boone
# 65363   touch bottl age give toasti character, impress...          Roger Voss
# ...

# %% [markdown]
# ### using count vectorizer and tfidf transformer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect_Dic={}
X_train_counts_Dic={}
for name in names_array:
    count_vect_Dic[name]=CountVectorizer()
    X_train_counts_Dic[name]=count_vect_Dic[name].fit_transform(Training_Dic[name].tokenize)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(Train_set.tokenize)
X_train_counts.shape
count_vect.vocabulary_
# Out:
# {'friend': 6695,
#  'flavorful': 6337,
#  'offer': 11214,
#  'bright': 2350,
#  'butter': 2592,
#  'fruit': 6747,
#  'aromas': 1172,
#  'opul': 11333,
#  'pear': 11820,
#  'bake': 1451,
#  'spice': 15159,
#  'flavor': 6335,
#  'lingering': 9355,
#  'vanilla': 17378,
#  'lik': 9295,
#  'finish': 6246,
#  'textur': 16317,
#  'plush': 12283,
#  'balanc': 1459,
#  'lean': 9134,
#  'toward': 16653,
#  'ripe': 13568,
#  'rich': 13508,
#  'variet': 17391,
#  'familiar': 6023,
#  'aroma': 1171,
#  'petrol': 12016,
#  'white': 17967,
#  'set': 14409,
#  'tight': 16472,
#  'acid': 493,
#  'palat': 11624,
#  'lemon': 9196,
#  'lim': 9316,
#  'nectarin': 10841,
#  'flavors': 6341,
#  'tast': 16158,
#  'pithi': 12173,
#  'lose': 9502,
#  'clariti': 3433,
#  'zest': 18308,
#  'wind': 18043,
#  'down': 5085,
#  'salin': 13918,
#  'almost': 797,
#  'dilut': 4852,
#  'nose': 11047,
#  'beli': 1723,
#  'richer': 13511,
#  'banana': 1486,
#  'control': 3961,
#  'profile': 12655,
#  'mouth': 10602,
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer_Dic={}
X_train_tfidf_Dic={}

for name in names_array:
    tfidf_transformer_Dic[name]=TfidfTransformer()
    X_train_tfidf_Dic[name]=tfidf_transformer_Dic[name].fit_transform(X_train_counts_Dic[name])

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (45168, 18353)

# %% [markdown]
# ### Model Testing

# %%
results_df=pd.DataFrame()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# %%
Naive_Dic={}
for name in names_array:
    Naive_Dic[name]=MultinomialNB()
    Naive_Dic[name].fit(X_train_tfidf_Dic[name], Training_Dic[name]['class'])

# %%
nb = MultinomialNB()
nb.fit(X_train_tfidf, Train_set['class'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# printing of individualized datasets and models
for name in names_array:
    print(name+" training score")
    print(Naive_Dic[name].score(X_train_tfidf_Dic[name], Training_Dic[name]['class']))
    print("--------------------")
# Out:
# Alexander Peartree training score
# 0.9194630872483222
# --------------------
# Jeff Jenssen training score
# 0.8835978835978836
# --------------------
# Mike DeSimone training score
# 0.7866666666666666
# --------------------
# Susan Kostrzewa training score
# 0.8366336633663366
# --------------------
# Lauren Buzzeo training score
# 0.8707729468599034
# --------------------
# Anne Krebiehl MW training score
# 0.8639921722113503
# --------------------
# Jim Gordon training score
# 0.8922764227642277
# --------------------
# Kerin O’Keefe training score
# 0.8887399463806971
# --------------------
# Joe Czerwinski training score
# 0.9076733688961839
# --------------------
# Anna Lee C. Iijima training score
# 0.8706929926442122
# --------------------
# Sean P. Sullivan training score
# 0.8840941512125535
# --------------------
# Matt Kettmann training score
# 0.771404821280133
# --------------------
# Michael Schachner training score
# 0.8847954406676165
# --------------------
# ...

# %%
# testing with kfolds to ensure accuracy over several splits
for name in names_array:
    nbf = MultinomialNB()
    scores = cross_val_score(nbf, X_train_tfidf_Dic[name],Training_Dic[name]['class'],cv=5)
    print(name)
    print(scores)
    print("-----")
# Out:
# Alexander Peartree
# [0.90322581 0.90322581 0.93103448 0.93103448 0.93103448]
# -----
# Jeff Jenssen
# [0.65789474 0.65789474 0.71052632 0.57894737 0.7027027 ]
# -----
# Mike DeSimone
# [0.73333333 0.73333333 0.73333333 0.73333333 0.73333333]
# -----
# Susan Kostrzewa
# [0.82716049 0.82716049 0.82716049 0.82716049 0.825     ]
# -----
# Lauren Buzzeo
# [0.82634731 0.77710843 0.83030303 0.77575758 0.8       ]
# -----
# Anne Krebiehl MW
# [0.85853659 0.85853659 0.85853659 0.8627451  0.86206897]
# -----
# Jim Gordon
# [0.8071066  0.82994924 0.79949239 0.80203046 0.81887755]
# -----
# Kerin O’Keefe
# [0.85267857 0.81919643 0.81919643 0.83928571 0.88340807]
# -----
# Joe Czerwinski
# [0.79713115 0.78278689 0.76434426 0.77823409 0.781893  ]
# -----
# Anna Lee C. Iijima
# [0.80464217 0.82011605 0.83365571 0.80620155 0.78875969]
# -----
# Sean P. Sullivan
# [0.82740214 0.85587189 0.81964286 0.81428571 0.82142857]
# -----
# Matt Kettmann
# ...

# %%
#general mutlinomial test
print("Total Score")
print(nb.score(X_train_tfidf, Train_set['class']))
# Out:
# Total Score
# 0.82538522848034

# %%
nbf = MultinomialNB()
scores = cross_val_score(nbf,X_train_tfidf,Train_set['class'],cv=5)
print(scores)
# Out:
# [0.80077476 0.79654638 0.79563822 0.7974095  0.79043507]

# %%
X_test_counts_Dic={}
X_test_tfidf_Dic={}
for name in names_array:
    X_test_counts_Dic[name]=count_vect_Dic[name].transform(Test_Dic[name].tokenize)
    X_test_tfidf_Dic[name]=tfidf_transformer_Dic[name].transform(X_test_counts_Dic[name])

# %%
X_test_counts = count_vect.transform(Test_set.tokenize)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
X_test_tfidf.shape
# Out:
# (11292, 18353)

# %%
predict_Dic={}
for name in names_array:
    predict_Dic[name]=Naive_Dic[name].predict(X_test_tfidf_Dic[name])

# %%
predict = nb.predict(X_test_tfidf)

# %%
#now seeing how it will predict the test split
for name in names_array:
    print(name+" Test Score")
    print(metrics.accuracy_score(Test_Dic[name]['class'], predict_Dic[name]))
    print("-------------------")
# Out:
# Alexander Peartree Test Score
# 0.9210526315789473
# -------------------
# Jeff Jenssen Test Score
# 0.7291666666666666
# -------------------
# Mike DeSimone Test Score
# 0.7719298245614035
# -------------------
# Susan Kostrzewa Test Score
# 0.7821782178217822
# -------------------
# Lauren Buzzeo Test Score
# 0.821256038647343
# -------------------
# Anne Krebiehl MW Test Score
# 0.87109375
# -------------------
# Jim Gordon Test Score
# 0.6463414634146342
# -------------------
# Kerin O’Keefe Test Score
# 0.7821428571428571
# -------------------
# Joe Czerwinski Test Score
# 0.7147540983606557
# -------------------
# Anna Lee C. Iijima Test Score
# 0.7708978328173375
# -------------------
# Sean P. Sullivan Test Score
# 0.8105413105413105
# -------------------
# Matt Kettmann Test Score
# 0.7153931339977851
# -------------------
# Michael Schachner Test Score
# 0.8242473555736372
# -------------------
# Paul Gregutt Test Score
# 0.7320916905444126
# -------------------
# ...

# %%
# general
print("Total Test Set Score:")
print(metrics.accuracy_score(Test_set['class'], predict))
# Out:
# Total Test Set Score:
# 0.7619553666312433

# %%
# confusion matrix to see how everything is being categorized
matrix_main=np.array([[0,0],[0,0]])
for name in names_array:
    print(name+" Confusion Matrix")
    print(metrics.confusion_matrix(Test_Dic[name]['class'], predict_Dic[name]))
    matrix_main=matrix_main+metrics.confusion_matrix(Test_Dic[name]['class'], predict_Dic[name])
    print("-----------------------")
    
print(matrix_main)
# Out:
# Alexander Peartree Confusion Matrix
# [[35  0]
#  [ 3  0]]
# -----------------------
# Jeff Jenssen Confusion Matrix
# [[18  2]
#  [11 17]]
# -----------------------
# Mike DeSimone Confusion Matrix
# [[ 0 13]
#  [ 0 44]]
# -----------------------
# Susan Kostrzewa Confusion Matrix
# [[79  0]
#  [22  0]]
# -----------------------
# Lauren Buzzeo Confusion Matrix
# [[134   3]
#  [ 34  36]]
# -----------------------
# Anne Krebiehl MW Confusion Matrix
# [[  0  33]
#  [  0 223]]
# -----------------------
# Jim Gordon Confusion Matrix
# [[ 84 164]
#  [ 10 234]]
# -----------------------
# Kerin O’Keefe Confusion Matrix
# [[254  16]
#  [106 184]]
# -----------------------
# Joe Czerwinski Confusion Matrix
# [[288  25]
#  [149 148]]
# -----------------------
# Anna Lee C. Iijima Confusion Matrix
# [[244  89]
#  [ 59 254]]
# -----------------------
# Sean P. Sullivan Confusion Matrix
# [[316  28]
#  [105 253]]
# -----------------------
# Matt Kettmann Confusion Matrix
# [[ 34 250]
# ...

# %%
#test to ensure matrix shape works properly
a,b=matrix_main.shape
print(a)
# Out:
# 2

# %%
#general matrix, not very useful
metrics.confusion_matrix(Test_set['class'], predict)
# Out:
# array([[3457, 1990],
#        [ 698, 5147]], dtype=int64)

# %%
#[[TN,FP],
#[FN,TP]]

# %%
# matrix_accuracy() returns decimal notation of matrix accuracy
def matrix_accuracy(matrix):
    a,b=matrix.shape
    true_values=0
    all_values=0
    for count in range(a):
        for counts in range(b):
            all_values=all_values+matrix[count][counts]
            if(count==counts):
                true_values=true_values+matrix[count][counts]
    return(true_values/all_values)

# %%
# matrix_percison() returns decimal notation of matrix percision
def matrix_percision(matrix):
    return(matrix[1][1]/(matrix[1][1]+matrix[0][1]))

# %%
# matrix_recall() returns decimal notation of matrix precall
def matrix_recall(matrix):
    return(matrix[1][1]/(matrix[1][1]+matrix[1][0]))

# %%
# matrix_f1() returns decimal notation of matrix f1 score
def matrix_f1(matrix):
    return(2*(matrix_percision(matrix)*matrix_recall(matrix))/(matrix_percision(matrix)+matrix_recall(matrix)))

# %% [markdown]
# ## Testing the different methods on naive bayes
# ### Individuals versus general model
# #### General accuracy
# Interestingly the individuals achieved a slightly higher accuracy score over the general model. The way this was tested is by confusion matrix, in order to account for the various sizes of samples throughout the model
# #### General precision

# %%
#creating a data frame to hold results of all tests
Results_DF = pd.DataFrame(columns=['General_Class','Divided_Class','Difference_Class'])
Results_DF = Results_DF.append({'General_Class' : metrics.accuracy_score(Test_set['class'], predict) , 'Divided_Class' : matrix_accuracy(matrix_main), 'Difference_Class': (metrics.accuracy_score(Test_set['class'], predict)-matrix_accuracy(matrix_main))} , ignore_index=True)
Results_DF = Results_DF.append({'General_Class' : metrics.precision_score(Test_set['class'], predict) , 'Divided_Class' : matrix_percision(matrix_main), 'Difference_Class': (metrics.precision_score(Test_set['class'], predict)-matrix_percision(matrix_main))} , ignore_index=True)
Results_DF = Results_DF.append({'General_Class' : metrics.recall_score(Test_set['class'],predict) , 'Divided_Class' : matrix_recall(matrix_main), 'Difference_Class': (metrics.recall_score(Test_set['class'],predict)-matrix_recall(matrix_main))} , ignore_index=True)
Results_DF = Results_DF.append({'General_Class' : metrics.f1_score(Test_set['class'],predict) , 'Divided_Class' : matrix_f1(matrix_main), 'Difference_Class': (metrics.f1_score(Test_set['class'],predict)-matrix_f1(matrix_main))} , ignore_index=True)
Results_DF.index=['Accuracy','Precision','Recall','F1']

# %%
Results_DF
# Out:
#            General_Class  Divided_Class  Difference_Class
# Accuracy        0.761955       0.760333          0.001623
# Precision       0.721171       0.757521         -0.036349
# Recall          0.880582       0.786916          0.093665
# F1              0.792944       0.771939          0.021005

# %% [markdown]
# ### dividing general sets into individual subsets
# This is done to determine delta accuracy between reveiwers in general and individualized sets

# %%
Div_Acc_DF=pd.DataFrame(columns=['General_Acc','Divided_Acc','Difference_Acc'])

# %%
subgroup_Dic={}
for names in names_array:
    subgroup_Dic[names]=Test_set[Test_set['taster_name']==names]

# %%
subgroup_class_Dic={}
for names in names_array:
    subgroup_class_Dic[names]=subgroup_Dic[names]['class']
    subgroup_Dic[names]=count_vect.transform(subgroup_Dic[names].tokenize)
    subgroup_Dic[names]=tfidf_transformer.transform(subgroup_Dic[names])
    subgroup_Dic[names]=nb.predict(subgroup_Dic[names])

# %%
for names in names_array:
    print(names+'General confusion matrix')
    print(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names]))
    print("--------------------------")
# Out:
# Alexander PeartreeGeneral confusion matrix
# [[21 14]
#  [ 0  6]]
# --------------------------
# Jeff JenssenGeneral confusion matrix
# [[15 16]
#  [ 6 18]]
# --------------------------
# Mike DeSimoneGeneral confusion matrix
# [[12  6]
#  [ 6 35]]
# --------------------------
# Susan KostrzewaGeneral confusion matrix
# [[36 34]
#  [ 3 15]]
# --------------------------
# Lauren BuzzeoGeneral confusion matrix
# [[106  27]
#  [ 16  57]]
# --------------------------
# Anne Krebiehl MWGeneral confusion matrix
# [[ 21  11]
#  [ 16 195]]
# --------------------------
# Jim GordonGeneral confusion matrix
# [[188  73]
#  [ 48 201]]
# --------------------------
# Kerin O’KeefeGeneral confusion matrix
# [[185 103]
#  [ 31 252]]
# --------------------------
# Joe CzerwinskiGeneral confusion matrix
# [[233 104]
#  [ 67 233]]
# --------------------------
# Anna Lee C. IijimaGeneral confusion matrix
# [[167 152]
#  [ 27 311]]
# --------------------------
# Sean P. SullivanGeneral confusion matrix
# ...

# %%
for names in names_array:
    Div_Acc_DF=Div_Acc_DF.append({
        'General_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names])),
        'Divided_Acc': matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names])),
        'Difference_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names]))-matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names]))}, ignore_index=True)

# %%
Div_Acc_DF.index=names_array

# %%
# accuracy results
Div_Acc_DF
# Out:
#                     General_Acc  Divided_Acc  Difference_Acc
# taster_name
# Alexander Peartree     0.658537     0.921053       -0.262516
# Jeff Jenssen           0.600000     0.729167       -0.129167
# Mike DeSimone          0.796610     0.771930        0.024680
# Susan Kostrzewa        0.579545     0.782178       -0.202633
# Lauren Buzzeo          0.791262     0.821256       -0.029994
# Anne Krebiehl MW       0.888889     0.871094        0.017795
# Jim Gordon             0.762745     0.646341        0.116404
# Kerin O’Keefe          0.765324     0.782143       -0.016819
# Joe Czerwinski         0.731554     0.714754        0.016800
# Anna Lee C. Iijima     0.727549     0.770898       -0.043348
# Sean P. Sullivan       0.781250     0.810541       -0.029291
# Matt Kettmann          0.750290     0.715393        0.034897
# Michael Schachner      0.840033     0.824247        0.015785
# Paul Gregutt           0.786791     0.732092        0.054699
# ...

# %%
Div_Per_DF=pd.DataFrame(columns=['General_Per','Divided_Per','Difference_Per'])

# %%
print("Subgroup of General   Specific group   Difference in Sets")
for names in names_array:
    Div_Per_DF=Div_Per_DF.append({
        'General_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names])),
        'Divided_Per': matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names])),
        'Difference_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names]))-matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names]))}, ignore_index=True)
# Out:
# Subgroup of General   Specific group   Difference in Sets
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in longlong_scalars

# %%
Div_Per_DF.index=names_array
# nan due to not having true positives to go off of

# %%
Div_Per_DF
# Out:
#                     General_Per  Divided_Per  Difference_Per
# taster_name
# Alexander Peartree     0.300000          NaN             NaN
# Jeff Jenssen           0.529412     0.894737       -0.365325
# Mike DeSimone          0.853659     0.771930        0.081729
# Susan Kostrzewa        0.306122          NaN             NaN
# Lauren Buzzeo          0.678571     0.923077       -0.244505
# Anne Krebiehl MW       0.946602     0.871094        0.075508
# Jim Gordon             0.733577     0.587940        0.145637
# Kerin O’Keefe          0.709859     0.920000       -0.210141
# Joe Czerwinski         0.691395     0.855491       -0.164097
# Anna Lee C. Iijima     0.671706     0.740525       -0.068819
# Sean P. Sullivan       0.761905     0.900356       -0.138451
# Matt Kettmann          0.761074     0.709977        0.051097
# Michael Schachner      0.737069     0.979592       -0.242523
# Paul Gregutt           0.782609     0.691293        0.091316
# ...

# %%
Div_Rec_DF=pd.DataFrame(columns=['General_Rec','Divided_Rec','Difference_Rec'])

# %%
print("Subgroup of General   Specific group   Difference in Sets")
for names in names_array:
    Div_Rec_DF=Div_Rec_DF.append({
        'General_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names])),
        'Divided_Rec': matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names])),
        'Difference_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_Dic[names], subgroup_Dic[names]))-matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_Dic[names]))}, ignore_index=True)
# Out:
# Subgroup of General   Specific group   Difference in Sets

# %%
Div_Rec_DF.index=names_array

# %%
Div_Rec_DF
# Out:
#                     General_Rec  Divided_Rec  Difference_Rec
# taster_name
# Alexander Peartree     1.000000     0.000000        1.000000
# Jeff Jenssen           0.750000     0.607143        0.142857
# Mike DeSimone          0.853659     1.000000       -0.146341
# Susan Kostrzewa        0.833333     0.000000        0.833333
# Lauren Buzzeo          0.780822     0.514286        0.266536
# Anne Krebiehl MW       0.924171     1.000000       -0.075829
# Jim Gordon             0.807229     0.959016       -0.151787
# Kerin O’Keefe          0.890459     0.634483        0.255977
# Joe Czerwinski         0.776667     0.498316        0.278350
# Anna Lee C. Iijima     0.920118     0.811502        0.108617
# Sean P. Sullivan       0.888889     0.706704        0.182185
# Matt Kettmann          0.938742     0.988691       -0.049950
# Michael Schachner      0.560656     0.309677        0.250978
# Paul Gregutt           0.889157     0.971570       -0.082413
# ...

# %%
#validation set
#cross validation within training set

# %%
Div_Results_DF = pd.merge(Div_Acc_DF, Div_Per_DF, on='taster_name')

# %%
Div_Results_DF = pd.merge(Div_Results_DF, Div_Rec_DF, on='taster_name')

# %%
Div_Results_DF
# Out:
#                     General_Acc  Divided_Acc  Difference_Acc  General_Per  \
# taster_name
# Alexander Peartree     0.658537     0.921053       -0.262516     0.300000
# Jeff Jenssen           0.600000     0.729167       -0.129167     0.529412
# Mike DeSimone          0.796610     0.771930        0.024680     0.853659
# Susan Kostrzewa        0.579545     0.782178       -0.202633     0.306122
# Lauren Buzzeo          0.791262     0.821256       -0.029994     0.678571
# Anne Krebiehl MW       0.888889     0.871094        0.017795     0.946602
# Jim Gordon             0.762745     0.646341        0.116404     0.733577
# Kerin O’Keefe          0.765324     0.782143       -0.016819     0.709859
# Joe Czerwinski         0.731554     0.714754        0.016800     0.691395
# Anna Lee C. Iijima     0.727549     0.770898       -0.043348     0.671706
# Sean P. Sullivan       0.781250     0.810541       -0.029291     0.761905
# ...

# %% [markdown]
# ## Testing other models for accuracy

# %%
from sklearn.linear_model import Ridge

# %%
rid = Ridge(alpha=1.0)
Y_train = Train_set['points'].values.reshape(-1,1)
rid.fit(X_train_tfidf, Y_train)
# sof max classifier 1- 10 and round ridge to comapre
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
lin_predict=rid.predict(X_test_tfidf)

# %%
print(lin_predict)
# Out:
# [[89.69224232]
#  [86.83137632]
#  [89.85960239]
#  ...
#  [88.97517879]
#  [90.138733  ]
#  [88.2163882 ]]

# %%
# much lowers than multinomial
Y_test=Test_set['points'].values.reshape(-1,1)
rid.score(X_test_tfidf,Y_test)
# Out:
# 0.4701535191046683

# %%
Linear_Dic={}
for name in names_array:
    Linear_Dic[name]=Ridge(alpha=1.0)
    Linear_Dic[name].fit(X_train_tfidf_Dic[name], Training_Dic[name]['points'].values.reshape(-1,1))

# %%
Lin_Predict_Dic={}
for name in names_array:
    Lin_Predict_Dic[name]=Linear_Dic[name].predict(X_test_tfidf_Dic[name])

# %%
# again much lower
for name in names_array:
    print(Linear_Dic[name].score(X_test_tfidf_Dic[name],Test_Dic[name]['points'].values.reshape(-1,1)))
    print("-------------------------")
# Out:
# 0.19477338278936485
# -------------------------
# 0.10956355442516219
# -------------------------
# 0.03091332972434546
# -------------------------
# 0.1360880023286326
# -------------------------
# 0.31114631511455215
# -------------------------
# 0.3925820475825478
# -------------------------
# 0.40253275454264403
# -------------------------
# 0.34584188837117824
# -------------------------
# 0.3598428252702601
# -------------------------
# 0.37697299027705133
# -------------------------
# 0.4463396570839121
# -------------------------
# 0.2957388713002579
# -------------------------
# 0.537832485955208
# -------------------------
# 0.47154117383191146
# -------------------------
# 0.39810654458906236
# -------------------------
# 0.39259156502037257
# -------------------------

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(criterion='entropy',n_estimators=400)

# %%
rfc.fit(X_train_tfidf, Train_set['class'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=400, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc.score(X_train_tfidf, Train_set['class'])
# Out:
# 0.9999778604321644

# %%
predict_rfc=rfc.predict(X_test_tfidf)

# %%
print(metrics.accuracy_score(Test_set['class'], predict_rfc))
# Out:
# 0.6935883811547998

# %%
print(metrics.confusion_matrix(Test_set['class'],predict_rfc))
# Out:
# [[2349 3098]
#  [ 362 5483]]

# %%
RandomForest_Dic={}
for name in names_array:
    RandomForest_Dic[name]= RandomForestClassifier(criterion='entropy',n_estimators=400)
    RandomForest_Dic[name].fit(X_train_tfidf_Dic[name], Training_Dic[name]['class'])

# %%
predict_rfc_Dic={}
for name in names_array:
    predict_rfc_Dic[name]=RandomForest_Dic[name].predict(X_test_tfidf_Dic[name])

# %%
matrix_main_rfc=[[0,0],[0,0]]
for name in names_array:
    print(name)
    print(metrics.accuracy_score(Test_Dic[name]['class'],predict_rfc_Dic[name]))
    print(metrics.confusion_matrix(Test_Dic[name]['class'],predict_rfc_Dic[name]))
    matrix_main_rfc+=metrics.confusion_matrix(Test_Dic[name]['class'],predict_rfc_Dic[name])
    print("---------")

print(matrix_main_rfc)
# Out:
# Alexander Peartree
# 0.9473684210526315
# [[35  0]
#  [ 2  1]]
# ---------
# Jeff Jenssen
# 0.6041666666666666
# [[ 1 19]
#  [ 0 28]]
# ---------
# Mike DeSimone
# 0.7719298245614035
# [[ 0 13]
#  [ 0 44]]
# ---------
# Susan Kostrzewa
# 0.7821782178217822
# [[79  0]
#  [22  0]]
# ---------
# Lauren Buzzeo
# 0.8647342995169082
# [[135   2]
#  [ 26  44]]
# ---------
# Anne Krebiehl MW
# 0.87109375
# [[  0  33]
#  [  0 223]]
# ---------
# Jim Gordon
# 0.5508130081300813
# [[ 31 217]
#  [  4 240]]
# ---------
# Kerin O’Keefe
# 0.7839285714285714
# [[235  35]
#  [ 86 204]]
# ---------
# Joe Czerwinski
# 0.7540983606557377
# [[261  52]
#  [ 98 199]]
# ---------
# Anna Lee C. Iijima
# 0.7275541795665634
# [[190 143]
#  [ 33 280]]
# ---------
# Sean P. Sullivan
# 0.7393162393162394
# [[176 168]
#  [ 15 343]]
# ---------
# Matt Kettmann
# 0.6854928017718716
# [[  0 284]
#  [  0 619]]
# ---------
# Michael Schachner
# 0.8795768917819365
# [[879  40]
#  [108 202]]
# ---------
# Paul Gregutt
# ...

# %%
Results_rfc_DF = pd.DataFrame(columns=['General_Class','Divided_Class','Difference_Class'])
Results_rfc_DF = Results_rfc_DF.append({'General_Class' : metrics.accuracy_score(Test_set['class'], predict_rfc) , 'Divided_Class' : matrix_accuracy(matrix_main_rfc), 'Difference_Class': (metrics.accuracy_score(Test_set['class'], predict_rfc)-matrix_accuracy(matrix_main_rfc))} , ignore_index=True)
Results_rfc_DF = Results_rfc_DF.append({'General_Class' : metrics.precision_score(Test_set['class'], predict_rfc) , 'Divided_Class' : matrix_percision(matrix_main_rfc), 'Difference_Class': (metrics.precision_score(Test_set['class'], predict_rfc)-matrix_percision(matrix_main_rfc))} , ignore_index=True)
Results_rfc_DF = Results_rfc_DF.append({'General_Class' : metrics.recall_score(Test_set['class'],predict_rfc) , 'Divided_Class' : matrix_recall(matrix_main_rfc), 'Difference_Class': (metrics.recall_score(Test_set['class'],predict_rfc)-matrix_recall(matrix_main_rfc))} , ignore_index=True)
Results_rfc_DF = Results_rfc_DF.append({'General_Class' : metrics.f1_score(Test_set['class'],predict_rfc) , 'Divided_Class' : matrix_f1(matrix_main_rfc), 'Difference_Class': (metrics.f1_score(Test_set['class'],predict_rfc)-matrix_f1(matrix_main_rfc))} , ignore_index=True)
Results_rfc_DF.index=['Accuracy','Precision','Recall','F1']

# %%
Results_rfc_DF
# Out:
#            General_Class  Divided_Class  Difference_Class
# Accuracy        0.693588       0.741393         -0.047805
# Precision       0.638970       0.707880         -0.068910
# Recall          0.938067       0.848386          0.089681
# F1              0.760155       0.771790         -0.011635

# %%
subgroup_rfc_Dic={}
for names in names_array:
    subgroup_rfc_Dic[names]=Test_set[Test_set['taster_name']==names]

# %%
subgroup_class_rfc_Dic={}
for names in names_array:
    subgroup_class_rfc_Dic[names]=subgroup_rfc_Dic[names]['class']
    subgroup_rfc_Dic[names]=count_vect.transform(subgroup_rfc_Dic[names].tokenize)
    subgroup_rfc_Dic[names]=tfidf_transformer.transform(subgroup_rfc_Dic[names])
    subgroup_rfc_Dic[names]=rfc.predict(subgroup_rfc_Dic[names])

# %%
for names in names_array:
    print(names+'General confusion matrix')
    print(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names]))
    print("--------------------------")
# Out:
# Alexander PeartreeGeneral confusion matrix
# [[ 6 29]
#  [ 1  5]]
# --------------------------
# Jeff JenssenGeneral confusion matrix
# [[ 5 26]
#  [ 7 17]]
# --------------------------
# Mike DeSimoneGeneral confusion matrix
# [[ 6 12]
#  [ 4 37]]
# --------------------------
# Susan KostrzewaGeneral confusion matrix
# [[15 55]
#  [ 2 16]]
# --------------------------
# Lauren BuzzeoGeneral confusion matrix
# [[41 92]
#  [ 0 73]]
# --------------------------
# Anne Krebiehl MWGeneral confusion matrix
# [[ 11  21]
#  [ 13 198]]
# --------------------------
# Jim GordonGeneral confusion matrix
# [[132 129]
#  [ 21 228]]
# --------------------------
# Kerin O’KeefeGeneral confusion matrix
# [[ 60 228]
#  [  1 282]]
# --------------------------
# Joe CzerwinskiGeneral confusion matrix
# [[188 149]
#  [ 33 267]]
# --------------------------
# Anna Lee C. IijimaGeneral confusion matrix
# [[ 54 265]
#  [ 13 325]]
# --------------------------
# Sean P. SullivanGeneral confusion matrix
# ...

# %%
Div_Acc_rfc_DF=pd.DataFrame(columns=['General_Acc','Divided_Acc','Difference_Acc'])
for names in names_array:
    print(names)
    Div_Acc_rfc_DF=Div_Acc_rfc_DF.append({
        'General_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names])),
        'Divided_Acc': matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names])),
        'Difference_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names]))-matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names]))}, ignore_index=True)

Div_Acc_rfc_DF.index=names_array
# Out:
# Alexander Peartree
# Jeff Jenssen
# Mike DeSimone
# Susan Kostrzewa
# Lauren Buzzeo
# Anne Krebiehl MW
# Jim Gordon
# Kerin O’Keefe
# Joe Czerwinski
# Anna Lee C. Iijima
# Sean P. Sullivan
# Matt Kettmann
# Michael Schachner
# Paul Gregutt
# Virginie Boone
# Roger Voss

# %%
Div_Acc_rfc_DF
# Out:
#                     General_Acc  Divided_Acc  Difference_Acc
# taster_name
# Alexander Peartree     0.268293     0.947368       -0.679076
# Jeff Jenssen           0.400000     0.604167       -0.204167
# Mike DeSimone          0.728814     0.771930       -0.043116
# Susan Kostrzewa        0.352273     0.782178       -0.429905
# Lauren Buzzeo          0.553398     0.864734       -0.311336
# Anne Krebiehl MW       0.860082     0.871094       -0.011011
# Jim Gordon             0.705882     0.550813        0.155069
# Kerin O’Keefe          0.598949     0.783929       -0.184979
# Joe Czerwinski         0.714286     0.754098       -0.039813
# Anna Lee C. Iijima     0.576865     0.727554       -0.150690
# Sean P. Sullivan       0.730114     0.739316       -0.009203
# Matt Kettmann          0.722416     0.685493        0.036923
# Michael Schachner      0.726825     0.879577       -0.152752
# Paul Gregutt           0.763101     0.687679        0.075422
# ...

# %%
Div_Per_rfc_DF=pd.DataFrame(columns=['General_Per','Divided_Per','Difference_Per'])
for names in names_array:
    Div_Per_rfc_DF=Div_Per_rfc_DF.append({
        'General_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names])),
        'Divided_Per': matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names])),
        'Difference_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names]))-matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names]))}, ignore_index=True)
Div_Per_rfc_DF.index=names_array
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in longlong_scalars

# %%
Div_Per_rfc_DF
# Out:
#                     General_Per  Divided_Per  Difference_Per
# taster_name
# Alexander Peartree     0.147059     1.000000       -0.852941
# Jeff Jenssen           0.395349     0.595745       -0.200396
# Mike DeSimone          0.755102     0.771930       -0.016828
# Susan Kostrzewa        0.225352          NaN             NaN
# Lauren Buzzeo          0.442424     0.956522       -0.514097
# Anne Krebiehl MW       0.904110     0.871094        0.033016
# Jim Gordon             0.638655     0.525164        0.113491
# Kerin O’Keefe          0.552941     0.853556       -0.300615
# Joe Czerwinski         0.641827     0.792829       -0.151002
# Anna Lee C. Iijima     0.550847     0.661939       -0.111091
# Sean P. Sullivan       0.696565     0.671233        0.025332
# Matt Kettmann          0.724477     0.685493        0.038984
# Michael Schachner      0.475610     0.834711       -0.359101
# Paul Gregutt           0.747525     0.652994        0.094530
# ...

# %%
Div_Rec_rfc_DF=pd.DataFrame(columns=['General_Rec','Divided_Rec','Difference_Rec'])
for names in names_array:
    Div_Rec_rfc_DF=Div_Rec_rfc_DF.append({
        'General_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names])),
        'Divided_Rec': matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names])),
        'Difference_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_rfc_Dic[names], subgroup_rfc_Dic[names]))-matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_rfc_Dic[names]))}, ignore_index=True)
Div_Rec_rfc_DF.index=names_array

# %%
Div_Rec_rfc_DF
# Out:
#                     General_Rec  Divided_Rec  Difference_Rec
# taster_name
# Alexander Peartree     0.833333     0.333333        0.500000
# Jeff Jenssen           0.708333     1.000000       -0.291667
# Mike DeSimone          0.902439     1.000000       -0.097561
# Susan Kostrzewa        0.888889     0.000000        0.888889
# Lauren Buzzeo          1.000000     0.628571        0.371429
# Anne Krebiehl MW       0.938389     1.000000       -0.061611
# Jim Gordon             0.915663     0.983607       -0.067944
# Kerin O’Keefe          0.996466     0.703448        0.293018
# Joe Czerwinski         0.890000     0.670034        0.219966
# Anna Lee C. Iijima     0.961538     0.894569        0.066970
# Sean P. Sullivan       0.921717     0.958101       -0.036383
# Matt Kettmann          0.975166     1.000000       -0.024834
# Michael Schachner      0.895082     0.651613        0.243469
# Paul Gregutt           0.909639     0.983931       -0.074292
# ...

# %%
Div_Results_rfc_DF = pd.merge(Div_Acc_rfc_DF, Div_Per_rfc_DF, on='taster_name')
Div_Results_rfc_DF = pd.merge(Div_Results_rfc_DF, Div_Rec_rfc_DF, on='taster_name')

# %%
Div_Results_rfc_DF
# Out:
#                     General_Acc  Divided_Acc  Difference_Acc  General_Per  \
# taster_name
# Alexander Peartree     0.268293     0.947368       -0.679076     0.147059
# Jeff Jenssen           0.400000     0.604167       -0.204167     0.395349
# Mike DeSimone          0.728814     0.771930       -0.043116     0.755102
# Susan Kostrzewa        0.352273     0.782178       -0.429905     0.225352
# Lauren Buzzeo          0.553398     0.864734       -0.311336     0.442424
# Anne Krebiehl MW       0.860082     0.871094       -0.011011     0.904110
# Jim Gordon             0.705882     0.550813        0.155069     0.638655
# Kerin O’Keefe          0.598949     0.783929       -0.184979     0.552941
# Joe Czerwinski         0.714286     0.754098       -0.039813     0.641827
# Anna Lee C. Iijima     0.576865     0.727554       -0.150690     0.550847
# Sean P. Sullivan       0.730114     0.739316       -0.009203     0.696565
# ...

# %% [markdown]
# ## Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
knc = KNeighborsClassifier(n_neighbors=10,weights='distance',n_jobs=-1)

# %%
knc.fit(X_train_tfidf, Train_set['class'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=10, p=2,
#            weights='distance')

# %%
knc.score(X_train_tfidf, Train_set['class'])
# Out:
# 0.9999778604321644

# %%
predict_knc=knc.predict(X_test_tfidf)

# %%
print(metrics.accuracy_score(Test_set['class'], predict_knc))
print(metrics.confusion_matrix(Test_set['class'],predict_rfc))
# Out:
# 0.5631420474672334
# [[2349 3098]
#  [ 362 5483]]

# %%
KNeighbors_Dic={}
for name in names_array:
    KNeighbors_Dic[name]= KNeighborsClassifier(n_neighbors=10,weights='distance',n_jobs=-1)
    KNeighbors_Dic[name].fit(X_train_tfidf_Dic[name], Training_Dic[name]['class'])

# %%
predict_knc_Dic={}
for name in names_array:
    predict_knc_Dic[name]=KNeighbors_Dic[name].predict(X_test_tfidf_Dic[name])

# %%
matrix_main_knc=[[0,0],[0,0]]
for name in names_array:
    print(name)
    print(metrics.accuracy_score(Test_Dic[name]['class'],predict_knc_Dic[name]))
    print(metrics.confusion_matrix(Test_Dic[name]['class'],predict_knc_Dic[name]))
    matrix_main_knc+=metrics.confusion_matrix(Test_Dic[name]['class'],predict_knc_Dic[name])
    print("---------")

print(matrix_main_knc)
# Out:
# Alexander Peartree
# 0.9210526315789473
# [[35  0]
#  [ 3  0]]
# ---------
# Jeff Jenssen
# 0.7291666666666666
# [[13  7]
#  [ 6 22]]
# ---------
# Mike DeSimone
# 0.7894736842105263
# [[ 2 11]
#  [ 1 43]]
# ---------
# Susan Kostrzewa
# 0.7425742574257426
# [[74  5]
#  [21  1]]
# ---------
# Lauren Buzzeo
# 0.7729468599033816
# [[127  10]
#  [ 37  33]]
# ---------
# Anne Krebiehl MW
# 0.8828125
# [[  3  30]
#  [  0 223]]
# ---------
# Jim Gordon
# 0.5487804878048781
# [[ 34 214]
#  [  8 236]]
# ---------
# Kerin O’Keefe
# 0.7464285714285714
# [[240  30]
#  [112 178]]
# ---------
# Joe Czerwinski
# 0.6672131147540984
# [[258  55]
#  [148 149]]
# ---------
# Anna Lee C. Iijima
# 0.7244582043343654
# [[228 105]
#  [ 73 240]]
# ---------
# Sean P. Sullivan
# 0.6068376068376068
# [[303  41]
#  [235 123]]
# ---------
# Matt Kettmann
# 0.7286821705426356
# [[ 76 208]
#  [ 37 582]]
# ---------
# Michael Schachner
# 0.7526444263628966
# [[912   7]
#  [297  13]]
# ---------
# Paul Gregutt
# ...

# %%
Results_knc_DF = pd.DataFrame(columns=['General_Class','Divided_Class','Difference_Class'])
Results_knc_DF = Results_knc_DF.append({'General_Class' : metrics.accuracy_score(Test_set['class'], predict_knc) , 'Divided_Class' : matrix_accuracy(matrix_main_knc), 'Difference_Class': (metrics.accuracy_score(Test_set['class'], predict_knc)-matrix_accuracy(matrix_main_knc))} , ignore_index=True)
Results_knc_DF = Results_knc_DF.append({'General_Class' : metrics.precision_score(Test_set['class'], predict_knc) , 'Divided_Class' : matrix_percision(matrix_main_knc), 'Difference_Class': (metrics.precision_score(Test_set['class'], predict_knc)-matrix_percision(matrix_main_knc))} , ignore_index=True)
Results_knc_DF = Results_knc_DF.append({'General_Class' : metrics.recall_score(Test_set['class'],predict_knc) , 'Divided_Class' : matrix_recall(matrix_main_knc), 'Difference_Class': (metrics.recall_score(Test_set['class'],predict_knc)-matrix_recall(matrix_main_knc))} , ignore_index=True)
Results_knc_DF = Results_knc_DF.append({'General_Class' : metrics.f1_score(Test_set['class'],predict_knc) , 'Divided_Class' : matrix_f1(matrix_main_knc), 'Difference_Class': (metrics.f1_score(Test_set['class'],predict_knc)-matrix_f1(matrix_main_knc))} , ignore_index=True)
Results_knc_DF.index=['Accuracy','Precision','Recall','F1']

# %%
Results_knc_DF
# Out:
#            General_Class  Divided_Class  Difference_Class
# Accuracy        0.563142       0.668555         -0.105413
# Precision       0.677708       0.728612         -0.050904
# Recall          0.297519       0.568853         -0.271334
# F1              0.413506       0.638897         -0.225391

# %%
subgroup_knc_Dic={}
for names in names_array:
    subgroup_knc_Dic[names]=Test_set[Test_set['taster_name']==names]

# %%
subgroup_class_knc_Dic={}
for names in names_array:
    subgroup_class_knc_Dic[names]=subgroup_knc_Dic[names]['class']
    subgroup_knc_Dic[names]=count_vect.transform(subgroup_knc_Dic[names].tokenize)
    subgroup_knc_Dic[names]=tfidf_transformer.transform(subgroup_knc_Dic[names])
    subgroup_knc_Dic[names]=rfc.predict(subgroup_knc_Dic[names])

# %%
for names in names_array:
    print(names+'General confusion matrix')
    print(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names]))
    print("--------------------------")
# Out:
# Alexander PeartreeGeneral confusion matrix
# [[ 6 29]
#  [ 1  5]]
# --------------------------
# Jeff JenssenGeneral confusion matrix
# [[ 5 26]
#  [ 7 17]]
# --------------------------
# Mike DeSimoneGeneral confusion matrix
# [[ 6 12]
#  [ 4 37]]
# --------------------------
# Susan KostrzewaGeneral confusion matrix
# [[15 55]
#  [ 2 16]]
# --------------------------
# Lauren BuzzeoGeneral confusion matrix
# [[41 92]
#  [ 0 73]]
# --------------------------
# Anne Krebiehl MWGeneral confusion matrix
# [[ 11  21]
#  [ 13 198]]
# --------------------------
# Jim GordonGeneral confusion matrix
# [[132 129]
#  [ 21 228]]
# --------------------------
# Kerin O’KeefeGeneral confusion matrix
# [[ 60 228]
#  [  1 282]]
# --------------------------
# Joe CzerwinskiGeneral confusion matrix
# [[188 149]
#  [ 33 267]]
# --------------------------
# Anna Lee C. IijimaGeneral confusion matrix
# [[ 54 265]
#  [ 13 325]]
# --------------------------
# Sean P. SullivanGeneral confusion matrix
# ...

# %%
Div_Acc_knc_DF=pd.DataFrame(columns=['General_Acc','Divided_Acc','Difference_Acc'])
for names in names_array:
    Div_Acc_knc_DF=Div_Acc_knc_DF.append({
        'General_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names])),
        'Divided_Acc': matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names])),
        'Difference_Acc': matrix_accuracy(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names]))-matrix_accuracy(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names]))}, ignore_index=True)

Div_Acc_knc_DF.index=names_array

# %%
Div_Per_knc_DF=pd.DataFrame(columns=['General_Per','Divided_Per','Difference_Per'])
for names in names_array:
    Div_Per_knc_DF=Div_Per_knc_DF.append({
        'General_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names])),
        'Divided_Per': matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names])),
        'Difference_Per': matrix_percision(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names]))-matrix_percision(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names]))}, ignore_index=True)
Div_Per_knc_DF.index=names_array
# Out:
# c:\users\juve\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in longlong_scalars

# %%
Div_Rec_knc_DF=pd.DataFrame(columns=['General_Rec','Divided_Rec','Difference_Rec'])
for names in names_array:
    Div_Rec_knc_DF=Div_Rec_knc_DF.append({
        'General_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names])),
        'Divided_Rec': matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names])),
        'Difference_Rec': matrix_recall(metrics.confusion_matrix(subgroup_class_knc_Dic[names], subgroup_knc_Dic[names]))-matrix_recall(metrics.confusion_matrix(Test_Dic[names]['class'], predict_knc_Dic[names]))}, ignore_index=True)
Div_Rec_knc_DF.index=names_array

# %%
Div_Results_knc_DF = pd.merge(Div_Acc_knc_DF, Div_Per_knc_DF, on='taster_name')
Div_Results_knc_DF = pd.merge(Div_Results_knc_DF, Div_Rec_knc_DF, on='taster_name')

# %%
Div_Results_knc_DF
# Out:
#                     General_Acc  Divided_Acc  Difference_Acc  General_Per  \
# taster_name
# Alexander Peartree     0.268293     0.921053       -0.652760     0.147059
# Jeff Jenssen           0.400000     0.729167       -0.329167     0.395349
# Mike DeSimone          0.728814     0.789474       -0.060660     0.755102
# Susan Kostrzewa        0.352273     0.742574       -0.390302     0.225352
# Lauren Buzzeo          0.553398     0.772947       -0.219549     0.442424
# Anne Krebiehl MW       0.860082     0.882812       -0.022730     0.904110
# Jim Gordon             0.705882     0.548780        0.157102     0.638655
# Kerin O’Keefe          0.598949     0.746429       -0.147479     0.552941
# Joe Czerwinski         0.714286     0.667213        0.047073     0.641827
# Anna Lee C. Iijima     0.576865     0.724458       -0.147594     0.550847
# Sean P. Sullivan       0.730114     0.606838        0.123276     0.696565
# ...

# %% [markdown]
# # Creating the ensemble model

# %%
Final_Gen_Results_DF = pd.concat([Results_DF, Results_rfc_DF, Results_knc_DF], keys=['Naive', 'Forest', 'Neighbor'])

# %%
# for simplicity sake we will only be looking at accuracy
Final_Gen_Results_DF
# Out:
#                     General_Class  Divided_Class  Difference_Class
# Naive    Accuracy        0.761955       0.760333          0.001623
#          Precision       0.721171       0.757521         -0.036349
#          Recall          0.880582       0.786916          0.093665
#          F1              0.792944       0.771939          0.021005
# Forest   Accuracy        0.693588       0.741393         -0.047805
#          Precision       0.638970       0.707880         -0.068910
#          Recall          0.938067       0.848386          0.089681
#          F1              0.760155       0.771790         -0.011635
# Neighbor Accuracy        0.563142       0.668555         -0.105413
#          Precision       0.677708       0.728612         -0.050904
#          Recall          0.297519       0.568853         -0.271334
#          F1              0.413506       0.638897         -0.225391

# %% [markdown]
# ## General Results
# Naive Bayes performs the best in both Accuracy and Precision, which is were we are focusing our results. This means that for non-specificied names or unknown names, this model will be used for predictions

# %%
Final_Div_Results_DF= pd.concat([Div_Results_DF, Div_Results_rfc_DF, Div_Results_knc_DF], keys=['Naive','Forest','Neighbor'])

# %%
Final_Div_Results_DF
# Out:
#                              General_Acc  Divided_Acc  Difference_Acc  \
#          taster_name
# Naive    Alexander Peartree     0.658537     0.921053       -0.262516
#          Jeff Jenssen           0.600000     0.729167       -0.129167
#          Mike DeSimone          0.796610     0.771930        0.024680
#          Susan Kostrzewa        0.579545     0.782178       -0.202633
#          Lauren Buzzeo          0.791262     0.821256       -0.029994
#          Anne Krebiehl MW       0.888889     0.871094        0.017795
#          Jim Gordon             0.762745     0.646341        0.116404
#          Kerin O’Keefe          0.765324     0.782143       -0.016819
#          Joe Czerwinski         0.731554     0.714754        0.016800
#          Anna Lee C. Iijima     0.727549     0.770898       -0.043348
#          Sean P. Sullivan       0.781250     0.810541       -0.029291
#          Matt Kettmann          0.750290     0.715393        0.034897
# ...

# %%
Final_Div_Results_DF[(Final_Div_Results_DF['Difference_Acc']<0)]
# noting individual models that preformed better than when inputted into the general model
# Out:
#                              General_Acc  Divided_Acc  Difference_Acc  \
#          taster_name
# Naive    Alexander Peartree     0.658537     0.921053       -0.262516
#          Jeff Jenssen           0.600000     0.729167       -0.129167
#          Susan Kostrzewa        0.579545     0.782178       -0.202633
#          Lauren Buzzeo          0.791262     0.821256       -0.029994
#          Kerin O’Keefe          0.765324     0.782143       -0.016819
#          Anna Lee C. Iijima     0.727549     0.770898       -0.043348
#          Sean P. Sullivan       0.781250     0.810541       -0.029291
#          Roger Voss             0.734976     0.765917       -0.030941
# Forest   Alexander Peartree     0.268293     0.947368       -0.679076
#          Jeff Jenssen           0.400000     0.604167       -0.204167
#          Mike DeSimone          0.728814     0.771930       -0.043116
#          Susan Kostrzewa        0.352273     0.782178       -0.429905
# ...

# %%
Naive_names = ['Jim Gordon','Jeff Jenssen','Kerin O’Keefe','Anna Lee C. Iijima','Virginie Boone','Roger Voss','Sean P. Sullivan']
Forest_names = ['Alexander Peartree','Susan Kostrzewa','Lauren Buzzeo','Michael Schachner']
Neighbor_names = ['Anne Krebiehl\xa0MW','Matt Kettmann']

# %%
# Jim Gordon Naive -- 1
# Alexander Peartree Forest -- 2
# Jeff Jenssen either Naive -- 1
# Susan Kostrzewa Naive or Forest, will choose forest -- 2
# Lauren Buzzeo Forest -- 2
# Kerin O'keefe Naive -- 1
# Anna Lee C. Ligima Naive -- 1
# Virginie Boone Naive -- 1
# Roger Voss Naive -- 1
# Sean P. Sullivan Naive -- 1
# Anna Krebiehl MW -- 3
# Matt Kettmann -- 3
# Micheal Schachner -- 2
# all else will be inputted to Naive Bayes General

# Ensemble_model() 
# input: must be of the same format as the original data set, mainly having a country, 
# taster_name, description, and points columns
# Output: Accuracy score of each reveiwer
def Ensemble_Model(dataframe):
    #get taster_name for modulization
    taster_array=dataframe.groupby('taster_name').count().sort_values('country')
    #set up sentiment dataframe from original data
    sentiment_features=pd.DataFrame()
    sentiment_features['tokenize']=dataframe['description']
    sentiment_features['tokenize']=sentiment_features['tokenize'].str.lower()
    sentiment_features['taster_name']=dataframe['taster_name']
    sentiment_features['class']=np.where(dataframe['points']>dataframe['points'].mean(),1,0)
    sentiment_features['points']=dataframe['points']
    #break up data to individual tasters
    sentiment_Dic = {}
    sentiment_class_Dic = {}
    for name in taster_array:
        sentiment_Dic[name] = sentiment_features[sentiment_features['taster_name']==name]
    stop = stopwords.words('english')
    stemmer = SnowballStemmer("english")
    for name in taster_array:
        sentiment_Dic[name].tokenize=sentiment_Dic[name].tokenize.str.split()
        sentiment_Dic[name].tokenize=sentiment_Dic[name].tokenize.apply(lambda x: [item for item in x if item not in stop])
        sentiment_Dic[name].tokenize=sentiment_Dic[name].tokenize.apply(lambda x:[stemmer.stem(item) for item in x])
        sentiment_Dic[name].tokenize=sentiment_Dic[name].tokenize.str.join(" ")
        sentiment_class_Dic[name]=sentiment_Dic[name]['class']
        # from this point we will divide into the appropiate model prep as noted above
        if name in Naive_names:
            sentiment_Dic[name]=count_vect_Dic[name].transform(sentiment_Dic[name].tokenize)
            sentiment_Dic[name]=tfidf_transformer_Dic[name].transform(sentiment_Dic[name])
            sentiment_Dic[name]=Naive_Dic[name].predict(sentiment_Dic[name])
            print(metrics.accuracy_score(sentiment_class_Dic[name], sentiment_Dic[name]))
        else if name in Forest_names:
            sentiment_Dic[name]=count_vect_Dic[name].transform(sentiment_Dic[name].tokenize)
            sentiment_Dic[name]=tfidf_transformer_Dic[name].transform(sentiment_Dic[name])
            sentiment_Dic[name]=RandomForest_Dic[name].predict(sentiment_Dic[name])
            print(metrics.accuracy_score(sentiment_class_Dic[name], sentiment_Dic[name]))
        else if name in Neighbor_names:
            sentiment_Dic[name]=count_vect_Dic[name].transform(sentiment_Dic[name].tokenize)
            sentiment_Dic[name]=tfidf_transformer_Dic[name].transform(sentiment_Dic[name])
            sentiment_Dic[name]= KNeighbors_Dic[name].predict(sentiment_Dic[name])
            print(metrics.accuracy_score(sentiment_class_Dic[name], sentiment_Dic[name]))
        else:
            sentiment_Dic[names]=count_vect.transform(sentiment_Dic[names].tokenize)
            sentiment_Dic[names]=tfidf_transformer.transform(sentiment_Dic[names])
            sentiment_Dic[names]=nb.predict(sentiment_Dic[names])
            print(metrics.accuracy_score(sentiment_class_Dic[name], sentiment_Dic[name]))
# Use tasters that were filtered out of dataframe to test
